# %% [markdown]
# ## Machine Learning
# # Tarea 1 : Problema de Clasificación y de Regresión Lineal
# ---
# __PROFESOR : Rodrigo Hernández__
#
# __ALUMNOS : Roy Barrera - José Pérez__

# %%
#Importacion de Librerias

#Manejo de path y carpetas
import os 

#Manejo de Data Frame
import pandas as pd

#Manejo de gráfica
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from pandas.plotting import scatter_matrix

#Magic para graficar dentro del notebook
# %matplotlib inline

#Disposición de argumentos de entrada para ML
import numpy as np

#Estadísticos de base
from scipy import stats

#Particiones para muestras
from sklearn.model_selection import train_test_split

#Clasificador Support Vector Machines
from sklearn.svm import SVC

#Métricas de desempeño
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

from sklearn.naive_bayes import GaussianNB

#Modelo de regresión Lineal

from sklearn.linear_model import LinearRegression
from sklearn import model_selection
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
df_t01 = pd.read_csv('Gasto_x_Familia.csv', sep=';', decimal='.')
df_t02=df_t01.drop(['Gastos','Ingresos','G8_Comunicaciones','G9_Recreacion','G10_Educacion'], axis=1)

# %%
import time
import warnings; 
warnings.simplefilter('ignore')

tot_total   = df_t02.shape[0]  # cantidad de datos del dataframe
particiones = 10
tot_grupo   = tot_total // particiones

model_p = SVC(kernel ='poly', cache_size=2048, gamma='auto' )

# %%
iteracion = 0

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')
# Out:
# >> 13/10/19 13:25:29 Iteracion :  1 , Desde Fila: 0  Hasta Fila: 494
#
# >> 13/10/19 13:25:29 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:28:06 modelo entrenado!
#
# >> 13/10/19 13:28:06 prediccion realizada!
#
# [[31 16  1]
#  [12 55  7]
#  [ 2 13 12]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.69      0.65      0.67        48
#      2.Medio       0.65      0.74      0.70        74
#       3.Alto       0.60      0.44      0.51        27
#
#    micro avg       0.66      0.66      0.66       149
#    macro avg       0.65      0.61      0.62       149
# weighted avg       0.66      0.66      0.65       149
#
# >> 13/10/19 13:28:06 modelo evaluado!
#
# ==================
# >> 13/10/19 13:28:06 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:28:06 modelo entrenado!
#
# >> 13/10/19 13:28:06 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 74  0]
#  [ 0 27  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.50      1.00      0.66        74
#       3.Alto       0.00      0.00      0.00        27
#
#    micro avg       0.50      0.50      0.50       149
#    macro avg       0.17      0.33      0.22       149
# weighted avg       0.25      0.50      0.33       149
#
# >> 13/10/19 13:28:06 modelo evaluado!
#
# ==================
# >> 13/10/19 13:28:06 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:28:06 modelo entrenado!
#
# >> 13/10/19 13:28:06 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 74  0]
#  [ 0 27  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.50      1.00      0.66        74
#       3.Alto       0.00      0.00      0.00        27
#
#    micro avg       0.50      0.50      0.50       149
#    macro avg       0.17      0.33      0.22       149
# weighted avg       0.25      0.50      0.33       149
#
# >> 13/10/19 13:28:06 modelo evaluado!
#
# ==================
# >> 13/10/19 13:28:06 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:28:06 modelo entrenado!
#
# >> 13/10/19 13:28:06 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.61
# Precisión en el set de Test: 0.63
# [[38  8  2]
#  [25 40  9]
#  [ 3  8 16]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.58      0.79      0.67        48
#      2.Medio       0.71      0.54      0.62        74
#       3.Alto       0.59      0.59      0.59        27
#
#    micro avg       0.63      0.63      0.63       149
#    macro avg       0.63      0.64      0.62       149
# weighted avg       0.65      0.63      0.63       149
#
# >> 13/10/19 13:28:06 modelo evaluado!
#
#
# >> 13/10/19 13:28:06 Iteracion :  2 , Desde Fila: 494  Hasta Fila: 988
#
# >> 13/10/19 13:28:06 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:31:01 modelo entrenado!
#
# >> 13/10/19 13:31:01 prediccion realizada!
#
# [[13 26  1]
#  [ 9 67  5]
#  [ 0 19  9]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.59      0.33      0.42        40
#      2.Medio       0.60      0.83      0.69        81
#       3.Alto       0.60      0.32      0.42        28
#
#    micro avg       0.60      0.60      0.60       149
#    macro avg       0.60      0.49      0.51       149
# weighted avg       0.60      0.60      0.57       149
#
# >> 13/10/19 13:31:01 modelo evaluado!
#
# ==================
# >> 13/10/19 13:31:01 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:31:01 modelo entrenado!
#
# >> 13/10/19 13:31:01 prediccion realizada!
#
# [[ 0 40  0]
#  [ 0 81  0]
#  [ 0 28  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        40
#      2.Medio       0.54      1.00      0.70        81
#       3.Alto       0.00      0.00      0.00        28
#
#    micro avg       0.54      0.54      0.54       149
#    macro avg       0.18      0.33      0.23       149
# weighted avg       0.30      0.54      0.38       149
#
# >> 13/10/19 13:31:01 modelo evaluado!
#
# ==================
# >> 13/10/19 13:31:01 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:31:01 modelo entrenado!
#
# >> 13/10/19 13:31:01 prediccion realizada!
#
# [[ 0 40  0]
#  [ 0 81  0]
#  [ 0 28  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        40
#      2.Medio       0.54      1.00      0.70        81
#       3.Alto       0.00      0.00      0.00        28
#
#    micro avg       0.54      0.54      0.54       149
#    macro avg       0.18      0.33      0.23       149
# weighted avg       0.30      0.54      0.38       149
#
# >> 13/10/19 13:31:01 modelo evaluado!
#
# ==================
# >> 13/10/19 13:31:01 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:31:01 modelo entrenado!
#
# >> 13/10/19 13:31:01 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.56
# Precisión en el set de Test: 0.50
# [[30  9  1]
#  [40 33  8]
#  [ 4 13 11]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.41      0.75      0.53        40
#      2.Medio       0.60      0.41      0.49        81
#       3.Alto       0.55      0.39      0.46        28
#
#    micro avg       0.50      0.50      0.50       149
#    macro avg       0.52      0.52      0.49       149
# weighted avg       0.54      0.50      0.49       149
#
# >> 13/10/19 13:31:01 modelo evaluado!
#
#
# >> 13/10/19 13:31:01 Iteracion :  3 , Desde Fila: 988  Hasta Fila: 1482
#
# >> 13/10/19 13:31:01 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:33:53 modelo entrenado!
#
# >> 13/10/19 13:33:53 prediccion realizada!
#
# [[17 22  1]
#  [10 60  8]
#  [ 0 22  9]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.63      0.42      0.51        40
#      2.Medio       0.58      0.77      0.66        78
#       3.Alto       0.50      0.29      0.37        31
#
#    micro avg       0.58      0.58      0.58       149
#    macro avg       0.57      0.49      0.51       149
# weighted avg       0.58      0.58      0.56       149
#
# >> 13/10/19 13:33:53 modelo evaluado!
#
# ==================
# >> 13/10/19 13:33:53 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:33:53 modelo entrenado!
#
# >> 13/10/19 13:33:53 prediccion realizada!
#
# [[ 0 40  0]
#  [ 0 78  0]
#  [ 0 31  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        40
#      2.Medio       0.52      1.00      0.69        78
#       3.Alto       0.00      0.00      0.00        31
#
#    micro avg       0.52      0.52      0.52       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.27      0.52      0.36       149
#
# >> 13/10/19 13:33:53 modelo evaluado!
#
# ==================
# >> 13/10/19 13:33:53 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:33:53 modelo entrenado!
#
# >> 13/10/19 13:33:53 prediccion realizada!
#
# [[ 0 40  0]
#  [ 0 78  0]
#  [ 0 31  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        40
#      2.Medio       0.52      1.00      0.69        78
#       3.Alto       0.00      0.00      0.00        31
#
#    micro avg       0.52      0.52      0.52       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.27      0.52      0.36       149
#
# >> 13/10/19 13:33:53 modelo evaluado!
#
# ==================
# >> 13/10/19 13:33:53 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:33:53 modelo entrenado!
#
# >> 13/10/19 13:33:53 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.57
# Precisión en el set de Test: 0.48
# [[30 10  0]
#  [36 36  6]
#  [ 6 20  5]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.42      0.75      0.54        40
#      2.Medio       0.55      0.46      0.50        78
#       3.Alto       0.45      0.16      0.24        31
#
#    micro avg       0.48      0.48      0.48       149
#    macro avg       0.47      0.46      0.42       149
# weighted avg       0.49      0.48      0.46       149
#
# >> 13/10/19 13:33:53 modelo evaluado!
#
#
# >> 13/10/19 13:33:53 Iteracion :  4 , Desde Fila: 1482  Hasta Fila: 1976
#
# >> 13/10/19 13:33:53 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:37:38 modelo entrenado!
#
# >> 13/10/19 13:37:38 prediccion realizada!
#
# [[17 27  0]
#  [14 57  5]
#  [ 0 18 11]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.55      0.39      0.45        44
#      2.Medio       0.56      0.75      0.64        76
#       3.Alto       0.69      0.38      0.49        29
#
#    micro avg       0.57      0.57      0.57       149
#    macro avg       0.60      0.51      0.53       149
# weighted avg       0.58      0.57      0.56       149
#
# >> 13/10/19 13:37:38 modelo evaluado!
#
# ==================
# >> 13/10/19 13:37:38 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:37:38 modelo entrenado!
#
# >> 13/10/19 13:37:38 prediccion realizada!
#
# [[ 0 44  0]
#  [ 0 76  0]
#  [ 0 29  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        44
#      2.Medio       0.51      1.00      0.68        76
#       3.Alto       0.00      0.00      0.00        29
#
#    micro avg       0.51      0.51      0.51       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.26      0.51      0.34       149
#
# >> 13/10/19 13:37:38 modelo evaluado!
#
# ==================
# >> 13/10/19 13:37:38 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:37:38 modelo entrenado!
#
# >> 13/10/19 13:37:38 prediccion realizada!
#
# [[ 0 44  0]
#  [ 0 76  0]
#  [ 0 29  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        44
#      2.Medio       0.51      1.00      0.68        76
#       3.Alto       0.00      0.00      0.00        29
#
#    micro avg       0.51      0.51      0.51       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.26      0.51      0.34       149
#
# >> 13/10/19 13:37:38 modelo evaluado!
#
# ==================
# >> 13/10/19 13:37:38 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:37:38 modelo entrenado!
#
# >> 13/10/19 13:37:38 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.50
# Precisión en el set de Test: 0.52
# [[39  5  0]
#  [45 27  4]
#  [ 3 14 12]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.45      0.89      0.60        44
#      2.Medio       0.59      0.36      0.44        76
#       3.Alto       0.75      0.41      0.53        29
#
#    micro avg       0.52      0.52      0.52       149
#    macro avg       0.60      0.55      0.52       149
# weighted avg       0.58      0.52      0.51       149
#
# >> 13/10/19 13:37:38 modelo evaluado!
#
#
# >> 13/10/19 13:37:38 Iteracion :  5 , Desde Fila: 1976  Hasta Fila: 2470
#
# >> 13/10/19 13:37:38 SVM con Kernel: LINEAL
# >> 13/10/19 13:40:31 modelo entrenado!
#
# >> 13/10/19 13:40:31 prediccion realizada!
#
# [[36 23  1]
#  [17 51  2]
#  [ 2 13  4]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.65      0.60      0.63        60
#      2.Medio       0.59      0.73      0.65        70
#       3.Alto       0.57      0.21      0.31        19
#
#    micro avg       0.61      0.61      0.61       149
#    macro avg       0.60      0.51      0.53       149
# weighted avg       0.61      0.61      0.60       149
#
# >> 13/10/19 13:40:31 modelo evaluado!
#
# ==================
# >> 13/10/19 13:40:31 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:40:31 modelo entrenado!
#
# >> 13/10/19 13:40:31 prediccion realizada!
#
# [[ 0 60  0]
#  [ 0 70  0]
#  [ 0 19  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        60
#      2.Medio       0.47      1.00      0.64        70
#       3.Alto       0.00      0.00      0.00        19
#
#    micro avg       0.47      0.47      0.47       149
#    macro avg       0.16      0.33      0.21       149
# weighted avg       0.22      0.47      0.30       149
#
# >> 13/10/19 13:40:31 modelo evaluado!
#
# ==================
# >> 13/10/19 13:40:31 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:40:31 modelo entrenado!
#
# >> 13/10/19 13:40:31 prediccion realizada!
#
# [[ 0 60  0]
#  [ 0 70  0]
#  [ 0 19  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        60
#      2.Medio       0.47      1.00      0.64        70
#       3.Alto       0.00      0.00      0.00        19
#
#    micro avg       0.47      0.47      0.47       149
#    macro avg       0.16      0.33      0.21       149
# weighted avg       0.22      0.47      0.30       149
#
# >> 13/10/19 13:40:31 modelo evaluado!
#
# ==================
# >> 13/10/19 13:40:31 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:40:31 modelo entrenado!
#
# >> 13/10/19 13:40:31 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.54
# Precisión en el set de Test: 0.57
# [[47 11  2]
#  [33 30  7]
#  [ 3  8  8]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.57      0.78      0.66        60
#      2.Medio       0.61      0.43      0.50        70
#       3.Alto       0.47      0.42      0.44        19
#
#    micro avg       0.57      0.57      0.57       149
#    macro avg       0.55      0.54      0.54       149
# weighted avg       0.58      0.57      0.56       149
#
# >> 13/10/19 13:40:31 modelo evaluado!
#
#
# >> 13/10/19 13:40:31 Iteracion :  6 , Desde Fila: 2470  Hasta Fila: 2964
#
# >> 13/10/19 13:40:31 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:43:17 modelo entrenado!
#
# >> 13/10/19 13:43:17 prediccion realizada!
#
# [[29 28  0]
#  [ 9 52  5]
#  [ 2 18  6]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.72      0.51      0.60        57
#      2.Medio       0.53      0.79      0.63        66
#       3.Alto       0.55      0.23      0.32        26
#
#    micro avg       0.58      0.58      0.58       149
#    macro avg       0.60      0.51      0.52       149
# weighted avg       0.61      0.58      0.57       149
#
# >> 13/10/19 13:43:17 modelo evaluado!
#
# ==================
# >> 13/10/19 13:43:17 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:43:17 modelo entrenado!
#
# >> 13/10/19 13:43:17 prediccion realizada!
#
# [[ 0 57  0]
#  [ 0 66  0]
#  [ 0 26  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        57
#      2.Medio       0.44      1.00      0.61        66
#       3.Alto       0.00      0.00      0.00        26
#
#    micro avg       0.44      0.44      0.44       149
#    macro avg       0.15      0.33      0.20       149
# weighted avg       0.20      0.44      0.27       149
#
# >> 13/10/19 13:43:17 modelo evaluado!
#
# ==================
# >> 13/10/19 13:43:17 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:43:17 modelo entrenado!
#
# >> 13/10/19 13:43:17 prediccion realizada!
#
# [[ 0 57  0]
#  [ 0 66  0]
#  [ 0 26  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        57
#      2.Medio       0.44      1.00      0.61        66
#       3.Alto       0.00      0.00      0.00        26
#
#    micro avg       0.44      0.44      0.44       149
#    macro avg       0.15      0.33      0.20       149
# weighted avg       0.20      0.44      0.27       149
#
# >> 13/10/19 13:43:17 modelo evaluado!
#
# ==================
# >> 13/10/19 13:43:17 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:43:17 modelo entrenado!
#
# >> 13/10/19 13:43:17 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.57
# Precisión en el set de Test: 0.58
# [[43 14  0]
#  [26 34  6]
#  [ 6 11  9]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.57      0.75      0.65        57
#      2.Medio       0.58      0.52      0.54        66
#       3.Alto       0.60      0.35      0.44        26
#
#    micro avg       0.58      0.58      0.58       149
#    macro avg       0.58      0.54      0.54       149
# weighted avg       0.58      0.58      0.57       149
#
# >> 13/10/19 13:43:17 modelo evaluado!
#
#
# >> 13/10/19 13:43:17 Iteracion :  7 , Desde Fila: 2964  Hasta Fila: 3458
#
# >> 13/10/19 13:43:17 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:45:19 modelo entrenado!
#
# >> 13/10/19 13:45:19 prediccion realizada!
#
# [[21 27  0]
#  [ 8 65  4]
#  [ 2 12 10]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.68      0.44      0.53        48
#      2.Medio       0.62      0.84      0.72        77
#       3.Alto       0.71      0.42      0.53        24
#
#    micro avg       0.64      0.64      0.64       149
#    macro avg       0.67      0.57      0.59       149
# weighted avg       0.66      0.64      0.63       149
#
# >> 13/10/19 13:45:19 modelo evaluado!
#
# ==================
# >> 13/10/19 13:45:19 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:45:19 modelo entrenado!
#
# >> 13/10/19 13:45:19 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 77  0]
#  [ 0 24  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.52      1.00      0.68        77
#       3.Alto       0.00      0.00      0.00        24
#
#    micro avg       0.52      0.52      0.52       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.27      0.52      0.35       149
#
# >> 13/10/19 13:45:19 modelo evaluado!
#
# ==================
# >> 13/10/19 13:45:19 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:45:19 modelo entrenado!
#
# >> 13/10/19 13:45:19 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 77  0]
#  [ 0 24  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.52      1.00      0.68        77
#       3.Alto       0.00      0.00      0.00        24
#
#    micro avg       0.52      0.52      0.52       149
#    macro avg       0.17      0.33      0.23       149
# weighted avg       0.27      0.52      0.35       149
#
# >> 13/10/19 13:45:19 modelo evaluado!
#
# ==================
# >> 13/10/19 13:45:19 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:45:19 modelo entrenado!
#
# >> 13/10/19 13:45:19 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.53
# Precisión en el set de Test: 0.62
# [[40  8  0]
#  [33 40  4]
#  [ 3  9 12]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.53      0.83      0.65        48
#      2.Medio       0.70      0.52      0.60        77
#       3.Alto       0.75      0.50      0.60        24
#
#    micro avg       0.62      0.62      0.62       149
#    macro avg       0.66      0.62      0.61       149
# weighted avg       0.65      0.62      0.61       149
#
# >> 13/10/19 13:45:19 modelo evaluado!
#
#
# >> 13/10/19 13:45:19 Iteracion :  8 , Desde Fila: 3458  Hasta Fila: 3952
#
# >> 13/10/19 13:45:19 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:47:37 modelo entrenado!
#
# >> 13/10/19 13:47:37 prediccion realizada!
#
# [[22 25  1]
#  [10 65  7]
#  [ 2  8  9]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.65      0.46      0.54        48
#      2.Medio       0.66      0.79      0.72        82
#       3.Alto       0.53      0.47      0.50        19
#
#    micro avg       0.64      0.64      0.64       149
#    macro avg       0.61      0.57      0.59       149
# weighted avg       0.64      0.64      0.63       149
#
# >> 13/10/19 13:47:37 modelo evaluado!
#
# ==================
# >> 13/10/19 13:47:37 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:47:37 modelo entrenado!
#
# >> 13/10/19 13:47:37 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 82  0]
#  [ 0 19  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.55      1.00      0.71        82
#       3.Alto       0.00      0.00      0.00        19
#
#    micro avg       0.55      0.55      0.55       149
#    macro avg       0.18      0.33      0.24       149
# weighted avg       0.30      0.55      0.39       149
#
# >> 13/10/19 13:47:37 modelo evaluado!
#
# ==================
# >> 13/10/19 13:47:37 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:47:37 modelo entrenado!
#
# >> 13/10/19 13:47:37 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 82  0]
#  [ 0 19  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.55      1.00      0.71        82
#       3.Alto       0.00      0.00      0.00        19
#
#    micro avg       0.55      0.55      0.55       149
#    macro avg       0.18      0.33      0.24       149
# weighted avg       0.30      0.55      0.39       149
#
# >> 13/10/19 13:47:37 modelo evaluado!
#
# ==================
# >> 13/10/19 13:47:37 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:47:37 modelo entrenado!
#
# >> 13/10/19 13:47:37 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.53
# Precisión en el set de Test: 0.57
# [[39  9  0]
#  [41 36  5]
#  [ 2  7 10]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.48      0.81      0.60        48
#      2.Medio       0.69      0.44      0.54        82
#       3.Alto       0.67      0.53      0.59        19
#
#    micro avg       0.57      0.57      0.57       149
#    macro avg       0.61      0.59      0.58       149
# weighted avg       0.62      0.57      0.56       149
#
# >> 13/10/19 13:47:37 modelo evaluado!
#
#
# >> 13/10/19 13:47:37 Iteracion :  9 , Desde Fila: 3952  Hasta Fila: 4446
#
# >> 13/10/19 13:47:37 SVM con Kernel: LINEAL
# >> 13/10/19 13:53:54 modelo entrenado!
#
# >> 13/10/19 13:53:54 prediccion realizada!
#
# [[26 28  1]
#  [14 53  4]
#  [ 3 13  7]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.60      0.47      0.53        55
#      2.Medio       0.56      0.75      0.64        71
#       3.Alto       0.58      0.30      0.40        23
#
#    micro avg       0.58      0.58      0.58       149
#    macro avg       0.58      0.51      0.52       149
# weighted avg       0.58      0.58      0.56       149
#
# >> 13/10/19 13:53:54 modelo evaluado!
#
# ==================
# >> 13/10/19 13:53:54 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:53:54 modelo entrenado!
#
# >> 13/10/19 13:53:54 prediccion realizada!
#
# [[ 0 55  0]
#  [ 0 71  0]
#  [ 0 23  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        55
#      2.Medio       0.48      1.00      0.65        71
#       3.Alto       0.00      0.00      0.00        23
#
#    micro avg       0.48      0.48      0.48       149
#    macro avg       0.16      0.33      0.22       149
# weighted avg       0.23      0.48      0.31       149
#
# >> 13/10/19 13:53:54 modelo evaluado!
#
# ==================
# >> 13/10/19 13:53:54 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:53:54 modelo entrenado!
#
# >> 13/10/19 13:53:54 prediccion realizada!
#
# [[ 0 55  0]
#  [ 0 71  0]
#  [ 0 23  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        55
#      2.Medio       0.48      1.00      0.65        71
#       3.Alto       0.00      0.00      0.00        23
#
#    micro avg       0.48      0.48      0.48       149
#    macro avg       0.16      0.33      0.22       149
# weighted avg       0.23      0.48      0.31       149
#
# >> 13/10/19 13:53:54 modelo evaluado!
#
# ==================
# >> 13/10/19 13:53:54 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:53:54 modelo entrenado!
#
# >> 13/10/19 13:53:54 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.54
# Precisión en el set de Test: 0.55
# [[41 12  2]
#  [33 32  6]
#  [ 3 11  9]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.53      0.75      0.62        55
#      2.Medio       0.58      0.45      0.51        71
#       3.Alto       0.53      0.39      0.45        23
#
#    micro avg       0.55      0.55      0.55       149
#    macro avg       0.55      0.53      0.53       149
# weighted avg       0.56      0.55      0.54       149
#
# >> 13/10/19 13:53:54 modelo evaluado!
#
#
# >> 13/10/19 13:53:54 Iteracion :  10 , Desde Fila: 4446  Hasta Fila: 4941
#
# >> 13/10/19 13:53:54 SVM con Kernel: LINEAL
#
# >> 13/10/19 13:55:42 modelo entrenado!
#
# >> 13/10/19 13:55:42 prediccion realizada!
#
# [[13 35  0]
#  [ 9 60  4]
#  [ 1 17 10]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.57      0.27      0.37        48
#      2.Medio       0.54      0.82      0.65        73
#       3.Alto       0.71      0.36      0.48        28
#
#    micro avg       0.56      0.56      0.56       149
#    macro avg       0.61      0.48      0.50       149
# weighted avg       0.58      0.56      0.53       149
#
# >> 13/10/19 13:55:42 modelo evaluado!
#
# ==================
# >> 13/10/19 13:55:42 SVM con Kernel: RADIAL
#
# >> 13/10/19 13:55:42 modelo entrenado!
#
# >> 13/10/19 13:55:42 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 73  0]
#  [ 0 28  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.49      1.00      0.66        73
#       3.Alto       0.00      0.00      0.00        28
#
#    micro avg       0.49      0.49      0.49       149
#    macro avg       0.16      0.33      0.22       149
# weighted avg       0.24      0.49      0.32       149
#
# >> 13/10/19 13:55:42 modelo evaluado!
#
# ==================
# >> 13/10/19 13:55:42 SVM con Kernel: SIGMOID
#
# >> 13/10/19 13:55:42 modelo entrenado!
#
# >> 13/10/19 13:55:42 prediccion realizada!
#
# [[ 0 48  0]
#  [ 0 73  0]
#  [ 0 28  0]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.00      0.00      0.00        48
#      2.Medio       0.49      1.00      0.66        73
#       3.Alto       0.00      0.00      0.00        28
#
#    micro avg       0.49      0.49      0.49       149
#    macro avg       0.16      0.33      0.22       149
# weighted avg       0.24      0.49      0.32       149
#
# >> 13/10/19 13:55:42 modelo evaluado!
#
# ==================
# >> 13/10/19 13:55:42 NAIVE BAYES GAUSSIANO
#
# >> 13/10/19 13:55:42 modelo entrenado!
#
# >> 13/10/19 13:55:42 prediccion realizada!
#
# Precisión en el set de Entrenamiento: 0.55
# Precisión en el set de Test: 0.54
# [[38 10  0]
#  [34 32  7]
#  [ 4 14 10]]
#               precision    recall  f1-score   support
#
#       1.Bajo       0.50      0.79      0.61        48
#      2.Medio       0.57      0.44      0.50        73
#       3.Alto       0.59      0.36      0.44        28
#
#    micro avg       0.54      0.54      0.54       149
#    macro avg       0.55      0.53      0.52       149
# weighted avg       0.55      0.54      0.52       149
#
# >> 13/10/19 13:55:42 modelo evaluado!
#
#
# >> 13/10/19 13:55:42 Fin

# %%
iteracion = 1

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 2

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 3

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 4

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 5

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 6

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 7

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 8

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')

# %%
iteracion = 9

desde = iteracion * tot_grupo    
hasta = desde + tot_grupo

print("==========================================================================================") 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "Iteracion : ", (iteracion +1), ", Desde Fila:", desde, " Hasta Fila:",hasta)

y=df_t02.loc[desde:hasta].Categoria.astype('category')
x=df_t02.loc[desde:hasta].drop('Categoria', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

print (">>", time.strftime("%d/%m/%y %H:%M:%S"), "SVM con Kernel: POLY ")

#entrenamiento
model_p.fit(x_train, y_train)  # a la maquina le pasa los parametro 
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'modelo entrenado!')

#prediccion
y_pred = model_p.predict(x_test)  # le pide a la maquina que prediga segun los test
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'prediccion realizada!')

#validacion 
print(confusion_matrix(y_test,y_pred))   
print(classification_report(y_test,y_pred))
print (">>", time.strftime("%d/%m/%y %H:%M:%S"), 'datos validados!')
